# %%
x=22
print(x)
# Out:
# 22

# %%
y='milky chocolate'
print(y)
# Out:
# milky chocolate

# %%
Y='vanilla'
print(Y)
# Out:
# vanilla

# %%
y='vanilla'
print(y)
# Out:
# vanilla

# %%
x,y,z='vanilla','chocolate','butterscotch'
print(x)
print(y)
print(z)
# Out:
# vanilla
# chocolate
# butterscotch

# %%
ice_cream=['centre_treat','double_choco','rocky_road']
x,y,z=ice_cream
print(x)
print(y)
print(z)
# Out:
# centre_treat
# double_choco
# rocky_road

# %%
#naming variables 
testvariable='icecream'
test_variable='ice cream'
_test_variable='ice_cream'
TestVariable='ice cream'
testVariable='ice cream'
testvariable2='ice cream'
2testvariable='ice cream'   #this can't be done, i.e., a variable can't start with an integer

print(testvariable)
# Out:
#   Cell In[8], line 8
#     2testvariable='ice cream'
#     ^
# SyntaxError: invalid decimal literal

# %%
x='ice cream'
y=' is my'
z=' favorite'
a='.'
print(x+y+z+a)
# Out:
# ice cream is my favorite.

# %%
x=22
y=23
print(x+y)
# Out:
# 45

# %%
a="ice cream"
b=2
print(a+b)   #you can't concatenate a string and an integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 a="ice cream"
#       2 b=2
# ----> 3 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(b,a)    #you can combine a string and an integer with the help of a comma(,)
# Out:
# 2 ice cream

# %%
print(6//3/2)
# Out:
# 1.0

# %%
print(3**2**2)
# Out:
# 81

# %%
print ('hello' *5)
# Out:
# hellohellohellohellohello

# %%
print (" i want ince cream " * 10)
# Out:
#  i want ince cream  i want ince cream  i want ince cream  i want ince cream  i want ince cream  i want ince cream  i want ince cream  i want ince cream  i want ince cream  i want ince cream

# %%
print(10+5*2)
# Out:
# 20

# %%
print((10+5)*2)
# Out:
# 30

# %%
a='data'
print(a*3)
# Out:
# datadatadata

# %%
print(True and False or True)
# Out:
# True

# %%
print('true' and 'false')
# Out:
# false

# %%
print('fasle' or 'true')
# Out:
# fasle

# %%
print("" and "hello")

# %%
print("" or "hello")
# Out:
# hello

# %%
print("python" and "datascience")
# Out:
# datascience

# %%
print(0 or 5)
# Out:
# 5

# %%
print(10 and 20)
# Out:
# 20

# %%
print(5 and 0)
# Out:
# 0

# %%
print(5 or 0)
# Out:
# 5

# %%
print("" and 10)

# %%
print("" or 10)
# Out:
# 10

# %%
print("AI" and 100)
# Out:
# 100

# %%
name=input("enter your name: ")
print("hello",name)
# Out:
# enter your name:  Aadya
# hello Aadya

# %%
age=input("enter your age: ")
print(age)
print(type(age))
# Out:
# enter your age:  22
# 22
# <class 'str'>

# %%
a=5
b=a
a=7
print(b)
# Out:
# 5

# %%
print(a)
# Out:
# 7

# %%
a=10
b=7
a+=b
print(a)
# Out:
# 17

# %%
print(b)
# Out:
# 7

# %%
msg,day,time='meeting','monday','9 pm'
print(msg,day,time)
# Out:
# meeting monday 9 pm

# %%
num1, num2 = 10,20
temp = num1
num1 = num2
num2 = temp
print(num1,num2)
# Out:
# 20 10

# %% [markdown]
# num1 = 43
# num2 =50
# num1,num2=num2,num1
# print(num1,num2)

# %%
n1=50
n2=67
n1,n2=n2,n1
print(n1,n2)
# Out:
# 67 50

# %%
a=int(input("enter first no: "))
b=int(input("enter sencond no: "))
print(a+b)
# Out:
# enter first no:  2
# enter sencond no:  4
# 6

# %%
print("10"+"20")
# Out:
# 1020

# %%
print(10+20)
# Out:
# 30

# %%
print("10"*3)
# Out:
# 101010

# %%
print(10*3)
# Out:
# 30

# %%
print(int("10")+int("20"))
# Out:
# 30
