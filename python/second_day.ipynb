# %%
age=input("enter your age: ")
print("I am ",age," years old.")
# Out:
# enter your age:  22
# I am  22  years old.

# %%
a=int(input("enter first no: "))
b=int(input("enter second no: "))
sum=a+b
print("the sum of the given two numbers is: ", sum)
# Out:
# enter first no:  18
# enter second no:  23
# the sum of the given two numbers is:  41

# %%
l=int(input("enter the length: "))
b=int(input("enter the breadth: "))
area=l*b
print("the area of the rectangle is: ",area, "sq. units")
# Out:
# enter the length:  58
# enter the breadth:  32
# the area of the rectangle is:  1856 sq. units

# %%
a=input("enter a number: ")
# Out:
# enter a number:  3

# %%
name=input("enter name: ")
print("hello ",name)
# Out:
# enter name:  Aadya
# hello  Aadya

# %%
a=input("enter a number: ")
print(a*3)
# Out:
# enter a number:  2
# 222

# %%
a=int(input("enter a number: "))
print(a*3)
# Out:
# enter a number:  2
# 6

# %%
name=input("enter name: ")
print(name," is learning data science.")
# Out:
# enter name:  aadya
# aadya  is learning data science.

# %%
a=float(input("enter a decimal number: "))
print(type(a))
# Out:
# enter a decimal number:  3.8
# <class 'float'>

# %%
print(10+int("20"))
# Out:
# 30

# %%
print(10+str(20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(10+str(20))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(float(5))
# Out:
# 5.0

# %%
print(int(5.9))
# Out:
# 5

# %%
print(bool(""))
# Out:
# False

# %%
#program for calculating user's current age based on birth year
birth_year=int(input("enter your birth year: "))
current_year=2026
age=current_year-birth_year
print(f"you are {age} years old" if 0<age<=100
      else "not alive anymore")
# Out:
# enter your birth year:  2000
# you are 26 years old
